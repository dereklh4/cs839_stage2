# %%
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import numpy as np
import pandas as pd

site= "http://www.metacritic.com/browse/albums/release-date/available/date?view=condensed&page"
hdr = {'User-Agent': 'Mozilla/5.0'}
req = Request(site,headers=hdr)
page = urlopen(req)
soup = BeautifulSoup(page)
df = pd.DataFrame(columns=['title','artist','release_date','genre','label','meta_score','user_score','links'])
df
for i in range(1):
    site = site+"="+str(i)
    for link in soup.find_all('div', class_="product_wrap"):
        url_link = (link.find('a')).get('href')
        title = (link.find('a')).contents[0]
        meta_score = link.find('div',class_="metascore_w").contents[0]
        artist = link.find('li',class_="product_artist").find('span',class_="data").contents[0]
        user_score = link.find('li',class_="product_avguserscore").find('span',class_="data").contents[0]
        release_date = link.find('li',class_="full_release_date").find('span',class_="data").contents[0]
        df = df.append({"title":title,"artist":artist,"release_date":release_date,"meta_score":meta_score,"user_score":user_score,"links":url_link},ignore_index=True)
df
# Out:
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
#                                                  title  \
# 0
#                             Lil Boat 2
#       ...
# 1
#                             American Utopia
#  ...
# 2
#                             White Is Relic/Ir...
# 3
#                             AmeriKKKant
#      ...
# 4
#                             Automata I
#       ...
# 5
#                             Cocoa Sugar
#      ...
# 6
#                             All That Must Be
# ...
# 7
#                             Tearing at the Se...
# 8
#                             I'm Bad Now
#      ...
# 9
#                             Firepower
#        ...
# 10
#                             Violence
#         ...
# 11
#                             Both Sides of the...
# 12
#                             Francis Trouble
#  ...
# 13
#                             Where Wilderness ...
# 14
#                             Belief
#           ...
# 15
#                             Everything Was Be...
# 16
#                             Moaning
#          ...
# 17
#                             Superorganism
#    ...
# 18
#                             Quiet and Peace
#  ...
# 19
#                             Le Kov
#           ...
# 20
#                             A Productive Coug...
# 21
#                             Clean
#            ...
# 22
#                             Dead Magic
#       ...
# 23
#                             Rare Birds
#       ...
# 24
#                             You're Not Alone
# ...
# 25
#                             All Nerve
#        ...
# 26
#                             Record
#           ...
# 27
#                             Historian
#        ...
# 28
#                             Felt
#             ...
# 29
#                             Drift
#            ...
# ..                                                 ...
# 170
#                             Mania
#            ...
# 171
#                             Earthtones
#       ...
# 172
#                             This Is Glue
#     ...
# 173
#                             Vision Songs, Vol...
# 174
#                             The Worm's Heart
# ...
# 175
#                             Burning Cities
#   ...
# 176
#                             Beautiful Despair...
# 177
#                             Impossible Star
#  ...
# 178
#                             P2
#               ...
# 179
#                             Wrong Creatures
#  ...
# 180
#                             No Cross No Crown...
# 181
#                             Encore
#           ...
# 182
#                             A Day With The Ho...
# 183
#                             Four Stones
#      ...
# 184
#                             Songs of Praise
#  ...
# 185
#                             Camila
#           ...
# 186
#                             Vale
#             ...
# 187
#                             Underworld
#       ...
# 188
#                             Ringthing
#        ...
# 189
#                             Blue Madonna
#     ...
# 190
#                             POST-
#            ...
# 191
#                             I
#                ...
# 192
#                             Rainbow Mirror
#   ...
# 193
#                             Huncho Jack, Jack...
# 194
#                             Saturation III
#   ...
# 195
#                             No One Ever Reall...
# 196
#                             Revival
#          ...
# 197
#                             Box Set #4: Curat...
# 198
#                             Pop 2 [Mixtape]
#  ...
# 199
#                             The Beautiful & D...
#
#                                     artist  release_date genre label  \
# 0                               Lil Yachty  Mar  9, 2018   NaN   NaN
# 1                              David Byrne  Mar  9, 2018   NaN   NaN
# 2                              Of Montreal  Mar  9, 2018   NaN   NaN
# 3                                 Ministry  Mar  9, 2018   NaN   NaN
# 4                Between the Buried and Me  Mar  9, 2018   NaN   NaN
# 5                            Young Fathers  Mar  9, 2018   NaN   NaN
# 6                        George FitzGerald  Mar  9, 2018   NaN   NaN
# 7    Nathaniel Rateliff & the Night Sweats  Mar  9, 2018   NaN   NaN
# 8                                 Nap Eyes  Mar  9, 2018   NaN   NaN
# 9                             Judas Priest  Mar  9, 2018   NaN   NaN
# 10                                 Editors  Mar  9, 2018   NaN   NaN
# 11                            Jimi Hendrix  Mar  9, 2018   NaN   NaN
# 12                     Albert Hammond, Jr.  Mar  9, 2018   NaN   NaN
# 13                                 Gengahr  Mar  9, 2018   NaN   NaN
# 14                          Richard Youngs  Mar  2, 2018   NaN   NaN
# 15                                    Moby  Mar  2, 2018   NaN   NaN
# 16                                 Moaning  Mar  2, 2018   NaN   NaN
# 17                           Superorganism  Mar  2, 2018   NaN   NaN
# 18                             Buffalo Tom  Mar  2, 2018   NaN   NaN
# 19                                  Gwenno  Mar  2, 2018   NaN   NaN
# 20                        Titus Andronicus  Mar  2, 2018   NaN   NaN
# 21                            Soccer Mommy  Mar  2, 2018   NaN   NaN
# 22                     Anna von Hausswolff  Mar  2, 2018   NaN   NaN
# 23                         Jonathan Wilson  Mar  2, 2018   NaN   NaN
# 24                             Andrew W.K.  Mar  2, 2018   NaN   NaN
# 25                            The Breeders  Mar  2, 2018   NaN   NaN
# 26                            Tracey Thorn  Mar  2, 2018   NaN   NaN
# 27                              Lucy Dacus  Mar  2, 2018   NaN   NaN
# 28                                   Suuns  Mar  2, 2018   NaN   NaN
# 29                                 The Men  Mar  2, 2018   NaN   NaN
# ..                                     ...           ...   ...   ...
# 170                           Fall Out Boy  Jan 19, 2018   NaN   NaN
# 171                                Bahamas  Jan 19, 2018   NaN   NaN
# 172                             Salad Boys  Jan 19, 2018   NaN   NaN
# 173                                Laraaji  Jan 19, 2018   NaN   NaN
# 174                              The Shins  Jan 19, 2018   NaN   NaN
# 175                                  Skids  Jan 19, 2018   NaN   NaN
# 176               Television Personalities  Jan 19, 2018   NaN   NaN
# 177                    Meat Beat Manifesto  Jan 19, 2018   NaN   NaN
# 178                              Dave East  Jan 16, 2018   NaN   NaN
# 179            Black Rebel Motorcycle Club  Jan 12, 2018   NaN   NaN
# 180                Corrosion of Conformity  Jan 12, 2018   NaN   NaN
# 181                          Anderson East  Jan 12, 2018   NaN   NaN
# 182                             Panda Bear  Jan 12, 2018   NaN   NaN
# 183                            Dean McPhee  Jan 12, 2018   NaN   NaN
# 184                                  Shame  Jan 12, 2018   NaN   NaN
# 185                         Camila Cabello  Jan 12, 2018   NaN   NaN
# 186                      Black Veil Brides  Jan 12, 2018   NaN   NaN
# 187                          Tonight Alive  Jan 12, 2018   NaN   NaN
# 188                                Jaguwar  Jan 12, 2018   NaN   NaN
# 189                                  BØRNS  Jan 12, 2018   NaN   NaN
# 190                        Jeff Rosenstock  Jan  2, 2018   NaN   NaN
# 191                             Kaukolampi  Dec 22, 2017   NaN   NaN
# 192                               Prurient  Dec 22, 2017   NaN   NaN
# 193                            Huncho Jack  Dec 21, 2017   NaN   NaN
# 194                           BROCKHAMPTON  Dec 15, 2017   NaN   NaN
# 195                                N.E.R.D  Dec 15, 2017   NaN   NaN
# 196                                 Eminem  Dec 15, 2017   NaN   NaN
# 197                              Fela Kuti  Dec 15, 2017   NaN   NaN
# 198                             Charli XCX  Dec 15, 2017   NaN   NaN
# 199                                 G-Eazy  Dec 15, 2017   NaN   NaN
#
#     meta_score user_score                                              links
# 0           52        tbd                       /music/lil-boat-2/lil-yachty
# 1           71        6.1                 /music/american-utopia/david-byrne
# 2           68        tbd     /music/white-is-relicirrealis-mood/of-montreal
# 3           59        5.4                        /music/amerikkkant/ministry
# 4           70        tbd        /music/automata-i/between-the-buried-and-me
# 5           89        9.0                   /music/cocoa-sugar/young-fathers
# 6           74        tbd          /music/all-that-must-be/george-fitzgerald
# 7           78        tbd  /music/tearing-at-the-seams/nathaniel-rateliff...
# 8           77        tbd                         /music/im-bad-now/nap-eyes
# 9           78        8.5                      /music/firepower/judas-priest
# 10          71        6.4                            /music/violence/editors
# 11          63        tbd          /music/both-sides-of-the-sky/jimi-hendrix
# 12          80        8.5           /music/francis-trouble/albert-hammond-jr
# 13          61        tbd              /music/where-wilderness-grows/gengahr
# 14          84        tbd                       /music/belief/richard-youngs
# 15          70        6.5  /music/everything-was-beautiful-and-nothing-hu...
# 16          68        6.0                             /music/moaning/moaning
# 17          75        8.2                 /music/superorganism/superorganism
# 18          72        tbd                 /music/quiet-and-peace/buffalo-tom
# 19          81        tbd                               /music/le-kov/gwenno
# 20          67        5.6         /music/a-productive-cough/titus-andronicus
# 21          78        8.8                          /music/clean/soccer-mommy
# 22          81        8.5              /music/dead-magic/anna-von-hausswolff
# 23          75        tbd                  /music/rare-birds/jonathan-wilson
# 24          77        8.2                   /music/youre-not-alone/andrew-wk
# 25          83        7.9                      /music/all-nerve/the-breeders
# 26          76        tbd                         /music/record/tracey-thorn
# 27          84        8.3                        /music/historian/lucy-dacus
# 28          69        tbd                                  /music/felt/suuns
# 29          64        tbd                               /music/drift/the-men
# ..         ...        ...                                                ...
# 170         58        6.1                          /music/mania/fall-out-boy
# 171         80        8.7                          /music/earthtones/bahamas
# 172         80        tbd                     /music/this-is-glue/salad-boys
# 173         73        tbd          /music/vision-songs-vol-1-reissue/laraaji
# 174         59        7.2                   /music/the-worms-heart/the-shins
# 175         64        tbd                        /music/burning-cities/skids
# 176         83        tbd  /music/beautiful-despair/television-personalities
# 177         72        tbd         /music/impossible-star/meat-beat-manifesto
# 178         83        tbd                                /music/p2/dave-east
# 179         69        7.1  /music/wrong-creatures/black-rebel-motorcycle-...
# 180         77        6.7   /music/no-cross-no-crown/corrosion-of-conformity
# 181         74        7.0                        /music/encore/anderson-east
# 182         74        tbd         /music/a-day-with-the-homies-ep/panda-bear
# 183         84        7.0                     /music/four-stones/dean-mcphee
# 184         84        7.9                       /music/songs-of-praise/shame
# 185         75        8.9                       /music/camila/camila-cabello
# 186         66        6.4                      /music/vale/black-veil-brides
# 187         63        6.3                    /music/underworld/tonight-alive
# 188         66        tbd                           /music/ringthing/jaguwar
# 189         67        8.0                           /music/blue-madonna/brns
# 190         90        7.9                       /music/post-/jeff-rosenstock
# 191         74        tbd                                /music/i/kaukolampi
# 192         72        tbd                     /music/rainbow-mirror/prurient
# 193         66        6.7         /music/huncho-jack-jack-huncho/huncho-jack
# 194         82        8.5                 /music/saturation-iii/brockhampton
# 195         74        7.6                /music/no-one-ever-really-dies/nerd
# 196         50        5.7                              /music/revival/eminem
# 197         87        tbd  /music/box-set-4-curated-by-erykah-badu-box-se...
# 198         84        8.1                    /music/pop-2-mixtape/charli-xcx
# 199         59        6.0                 /music/the-beautiful-damned/g-eazy
#
# [200 rows x 8 columns]

# %%
base_url = "http://www.metacritic.com/"
links = df['links']
genre_list = []
label_list = []
for link in links:
    albumn_link = base_url+link
    hdr = {'User-Agent': 'Mozilla/5.0'}
    req = Request(albumn_link,headers=hdr)
    page = urlopen(req)
    soup = BeautifulSoup(page)
    cropped = soup.find('div',class_="product_data_summary")
    label = cropped.find('li',class_="product_company").find('span',class_="data").contents[0]
    print(label)
    label_list.append(label)
    genre = cropped.find('li',class_="product_genre").find('span',class_="data").contents
    genre_list.append(genre)
    print(genre)

label_list
genre_list
# df['genre'] = genre_list
# df['label'] = label_list
#     df = df.append({"label":label,"genre":genre},ignore_index=True) 
df
# Out:
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# Quality Control
# ['Rap']
# Nonesuch
# ['Pop/Rock']
# Polyvinyl
# ['Pop/Rock']
# Nuclear Blast
# ['Pop/Rock']
# Sumerian Records
# ['Pop/Rock']
# Ninja Tune
# ['Rap']
# Domino
# ['Electronic']
# Fantasy
# ['Pop/Rock']
# Jagjaguwar
# ['Pop/Rock']
# Columbia
# ['Pop/Rock']
# PIAS
# ['Pop/Rock']
# Legacy
# ['Pop/Rock']
# Red Bull Records
# ['Pop/Rock']
# Transgressive
# ['Pop/Rock']
# O Genesis
# ['Alternative Pop/Rock']
# Mute US
# ['Electronic']
# Sub Pop
# ['Pop/Rock']
# Domino
# ['Pop/Rock']
# Schoolkids
# ['Pop/Rock']
# Heavenly
# ['Pop/Rock']
# Merge
# ['Pop/Rock']
# Fat Possum
# ['Pop/Rock']
# City Slang
# ['Pop/Rock']
# Bella Union
# ['Pop/Rock']
# BEE & El
# ['Pop/Rock']
# 4AD
# ['Pop/Rock']
# Merge
# ['Pop/Rock']
# Matador
# ['Pop/Rock']
# Secretly Canadian
# ['Pop/Rock']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-181-da620c6198cb> in <module>()
#       7     hdr = {'User-Agent': 'Mozilla/5.0'}
#       8     req = Request(albumn_link,headers=hdr)
# ----> 9     page = urlopen(req)
#      10     soup = BeautifulSoup(page)
#      11     cropped = soup.find('div',class_="product_data_summary")
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in http_open(self, req)
#    1344
#    1345     def http_open(self, req):
# -> 1346         return self.do_open(http.client.HTTPConnection, req)
#    1347
#    1348     http_request = AbstractHTTPHandler.do_request_
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1319             except OSError as err: # timeout error
#    1320                 raise URLError(err)
# -> 1321             r = h.getresponse()
#    1322         except:
#    1323             h.close()
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:
