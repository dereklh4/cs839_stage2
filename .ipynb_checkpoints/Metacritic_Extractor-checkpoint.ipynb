# %%
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import numpy as np
import pandas as pd

site= "http://www.metacritic.com/browse/albums/release-date/available/date?view=condensed&page"
hdr = {'User-Agent': 'Mozilla/5.0'}
req = Request(site,headers=hdr)
page = urlopen(req)
soup = BeautifulSoup(page)
df = pd.DataFrame(columns=['title','artist','release_date','genre','label','meta_score','user_score','links'])
df
for i in range(1,16):
    site = site+"="+str(i)
    for link in soup.find_all('div', class_="product_wrap"):
        url_link = (link.find('a')).get('href')
        title = (link.find('a')).contents[0]
        meta_score = link.find('div',class_="metascore_w").contents[0]
        artist = link.find('li',class_="product_artist").find('span',class_="data").contents[0]
        user_score = link.find('li',class_="product_avguserscore").find('span',class_="data").contents[0]
        release_date = link.find('li',class_="full_release_date").find('span',class_="data").contents[0]
        df = df.append({"title":title,"artist":artist,"release_date":release_date,"meta_score":meta_score,"user_score":user_score,"links":url_link},ignore_index=True)
df.to_csv("/afs/cs.wisc.edu/u/s/r/srujith/cs839_stage2/",index=False)
# Out:
# /u/s/r/srujith/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /u/s/r/srujith/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
#                                                   title  \
# 0
#                             Lil Boat 2
#       ...
# 1
#                             American Utopia
#  ...
# 2
#                             White Is Relic/Ir...
# 3
#                             AmeriKKKant
#      ...
# 4
#                             Automata I
#       ...
# 5
#                             Cocoa Sugar
#      ...
# 6
#                             All That Must Be
# ...
# 7
#                             Tearing at the Se...
# 8
#                             I'm Bad Now
#      ...
# 9
#                             Firepower
#        ...
# 10
#                             Violence
#         ...
# 11
#                             Both Sides of the...
# 12
#                             Francis Trouble
#  ...
# 13
#                             Where Wilderness ...
# 14
#                             A Work Of Heart
#  ...
# 15
#                             Belief
#           ...
# 16
#                             Everything Was Be...
# 17
#                             Moaning
#          ...
# 18
#                             Superorganism
#    ...
# 19
#                             Quiet and Peace
#  ...
# 20
#                             Le Kov
#           ...
# 21
#                             A Productive Coug...
# 22
#                             Clean
#            ...
# 23
#                             Dead Magic
#       ...
# 24
#                             Rare Birds
#       ...
# 25
#                             You're Not Alone
# ...
# 26
#                             All Nerve
#        ...
# 27
#                             Record
#           ...
# 28
#                             Historian
#        ...
# 29
#                             Felt
#             ...
# ...                                                 ...
# 2970
#                             I Like Fun
#       ...
# 2971
#                             Starcrawler
#      ...
# 2972
#                             Mania
#            ...
# 2973
#                             Earthtones
#       ...
# 2974
#                             This Is Glue
#     ...
# 2975
#                             Vision Songs, Vol...
# 2976
#                             The Worm's Heart
# ...
# 2977
#                             Burning Cities
#   ...
# 2978
#                             Beautiful Despair...
# 2979
#                             Impossible Star
#  ...
# 2980
#                             P2
#               ...
# 2981
#                             Wrong Creatures
#  ...
# 2982
#                             No Cross No Crown...
# 2983
#                             Encore
#           ...
# 2984
#                             A Day With The Ho...
# 2985
#                             Four Stones
#      ...
# 2986
#                             Songs of Praise
#  ...
# 2987
#                             Camila
#           ...
# 2988
#                             Vale
#             ...
# 2989
#                             Underworld
#       ...
# 2990
#                             Ringthing
#        ...
# 2991
#                             Blue Madonna
#     ...
# 2992
#                             POST-
#            ...
# 2993
#                             I
#                ...
# 2994
#                             Rainbow Mirror
#   ...
# 2995
#                             Huncho Jack, Jack...
# 2996
#                             Saturation III
#   ...
# 2997
#                             No One Ever Reall...
# 2998
#                             Revival
#          ...
# 2999
#                             Box Set #4: Curat...
#
#                                      artist  release_date genre label  \
# 0                                Lil Yachty  Mar  9, 2018   NaN   NaN
# 1                               David Byrne  Mar  9, 2018   NaN   NaN
# 2                               Of Montreal  Mar  9, 2018   NaN   NaN
# 3                                  Ministry  Mar  9, 2018   NaN   NaN
# 4                 Between the Buried and Me  Mar  9, 2018   NaN   NaN
# 5                             Young Fathers  Mar  9, 2018   NaN   NaN
# 6                         George FitzGerald  Mar  9, 2018   NaN   NaN
# 7     Nathaniel Rateliff & the Night Sweats  Mar  9, 2018   NaN   NaN
# 8                                  Nap Eyes  Mar  9, 2018   NaN   NaN
# 9                              Judas Priest  Mar  9, 2018   NaN   NaN
# 10                                  Editors  Mar  9, 2018   NaN   NaN
# 11                             Jimi Hendrix  Mar  9, 2018   NaN   NaN
# 12                      Albert Hammond, Jr.  Mar  9, 2018   NaN   NaN
# 13                                  Gengahr  Mar  9, 2018   NaN   NaN
# 14                                       Ty  Mar  2, 2018   NaN   NaN
# 15                           Richard Youngs  Mar  2, 2018   NaN   NaN
# 16                                     Moby  Mar  2, 2018   NaN   NaN
# 17                                  Moaning  Mar  2, 2018   NaN   NaN
# 18                            Superorganism  Mar  2, 2018   NaN   NaN
# 19                              Buffalo Tom  Mar  2, 2018   NaN   NaN
# 20                                   Gwenno  Mar  2, 2018   NaN   NaN
# 21                         Titus Andronicus  Mar  2, 2018   NaN   NaN
# 22                             Soccer Mommy  Mar  2, 2018   NaN   NaN
# 23                      Anna von Hausswolff  Mar  2, 2018   NaN   NaN
# 24                          Jonathan Wilson  Mar  2, 2018   NaN   NaN
# 25                              Andrew W.K.  Mar  2, 2018   NaN   NaN
# 26                             The Breeders  Mar  2, 2018   NaN   NaN
# 27                             Tracey Thorn  Mar  2, 2018   NaN   NaN
# 28                               Lucy Dacus  Mar  2, 2018   NaN   NaN
# 29                                    Suuns  Mar  2, 2018   NaN   NaN
# ...                                     ...           ...   ...   ...
# 2970                   They Might Be Giants  Jan 19, 2018   NaN   NaN
# 2971                            Starcrawler  Jan 19, 2018   NaN   NaN
# 2972                           Fall Out Boy  Jan 19, 2018   NaN   NaN
# 2973                                Bahamas  Jan 19, 2018   NaN   NaN
# 2974                             Salad Boys  Jan 19, 2018   NaN   NaN
# 2975                                Laraaji  Jan 19, 2018   NaN   NaN
# 2976                              The Shins  Jan 19, 2018   NaN   NaN
# 2977                                  Skids  Jan 19, 2018   NaN   NaN
# 2978               Television Personalities  Jan 19, 2018   NaN   NaN
# 2979                    Meat Beat Manifesto  Jan 19, 2018   NaN   NaN
# 2980                              Dave East  Jan 16, 2018   NaN   NaN
# 2981            Black Rebel Motorcycle Club  Jan 12, 2018   NaN   NaN
# 2982                Corrosion of Conformity  Jan 12, 2018   NaN   NaN
# 2983                          Anderson East  Jan 12, 2018   NaN   NaN
# 2984                             Panda Bear  Jan 12, 2018   NaN   NaN
# 2985                            Dean McPhee  Jan 12, 2018   NaN   NaN
# 2986                                  Shame  Jan 12, 2018   NaN   NaN
# 2987                         Camila Cabello  Jan 12, 2018   NaN   NaN
# 2988                      Black Veil Brides  Jan 12, 2018   NaN   NaN
# 2989                          Tonight Alive  Jan 12, 2018   NaN   NaN
# 2990                                Jaguwar  Jan 12, 2018   NaN   NaN
# 2991                                  BØRNS  Jan 12, 2018   NaN   NaN
# 2992                        Jeff Rosenstock  Jan  2, 2018   NaN   NaN
# 2993                             Kaukolampi  Dec 22, 2017   NaN   NaN
# 2994                               Prurient  Dec 22, 2017   NaN   NaN
# 2995                            Huncho Jack  Dec 21, 2017   NaN   NaN
# 2996                           BROCKHAMPTON  Dec 15, 2017   NaN   NaN
# 2997                                N.E.R.D  Dec 15, 2017   NaN   NaN
# 2998                                 Eminem  Dec 15, 2017   NaN   NaN
# 2999                              Fela Kuti  Dec 15, 2017   NaN   NaN
#
#      meta_score user_score                                              links
# 0            52        tbd                       /music/lil-boat-2/lil-yachty
# 1            71        6.1                 /music/american-utopia/david-byrne
# 2            68        tbd     /music/white-is-relicirrealis-mood/of-montreal
# 3            59        5.4                        /music/amerikkkant/ministry
# 4            70        tbd        /music/automata-i/between-the-buried-and-me
# 5            89        9.0                   /music/cocoa-sugar/young-fathers
# 6            74        tbd          /music/all-that-must-be/george-fitzgerald
# 7            78        tbd  /music/tearing-at-the-seams/nathaniel-rateliff...
# 8            77        tbd                         /music/im-bad-now/nap-eyes
# 9            78        8.5                      /music/firepower/judas-priest
# 10           71        6.4                            /music/violence/editors
# 11           63        tbd          /music/both-sides-of-the-sky/jimi-hendrix
# 12           80        8.5           /music/francis-trouble/albert-hammond-jr
# 13           61        tbd              /music/where-wilderness-grows/gengahr
# 14           71        tbd                          /music/a-work-of-heart/ty
# 15           84        tbd                       /music/belief/richard-youngs
# 16           70        6.5  /music/everything-was-beautiful-and-nothing-hu...
# 17           68        6.0                             /music/moaning/moaning
# 18           75        8.2                 /music/superorganism/superorganism
# 19           72        tbd                 /music/quiet-and-peace/buffalo-tom
# 20           81        tbd                               /music/le-kov/gwenno
# 21           67        5.6         /music/a-productive-cough/titus-andronicus
# 22           78        8.8                          /music/clean/soccer-mommy
# 23           81        8.5              /music/dead-magic/anna-von-hausswolff
# 24           75        tbd                  /music/rare-birds/jonathan-wilson
# 25           77        8.2                   /music/youre-not-alone/andrew-wk
# 26           83        7.9                      /music/all-nerve/the-breeders
# 27           76        tbd                         /music/record/tracey-thorn
# 28           84        8.3                        /music/historian/lucy-dacus
# 29           69        tbd                                  /music/felt/suuns
# ...         ...        ...                                                ...
# 2970         72        8.4             /music/i-like-fun/they-might-be-giants
# 2971         71        tbd                     /music/starcrawler/starcrawler
# 2972         58        6.1                          /music/mania/fall-out-boy
# 2973         80        8.7                          /music/earthtones/bahamas
# 2974         80        tbd                     /music/this-is-glue/salad-boys
# 2975         73        tbd          /music/vision-songs-vol-1-reissue/laraaji
# 2976         59        7.2                   /music/the-worms-heart/the-shins
# 2977         64        tbd                        /music/burning-cities/skids
# 2978         83        tbd  /music/beautiful-despair/television-personalities
# 2979         72        tbd         /music/impossible-star/meat-beat-manifesto
# 2980         83        tbd                                /music/p2/dave-east
# 2981         69        7.1  /music/wrong-creatures/black-rebel-motorcycle-...
# 2982         77        6.7   /music/no-cross-no-crown/corrosion-of-conformity
# 2983         74        7.0                        /music/encore/anderson-east
# 2984         74        tbd         /music/a-day-with-the-homies-ep/panda-bear
# 2985         84        7.0                     /music/four-stones/dean-mcphee
# 2986         84        7.9                       /music/songs-of-praise/shame
# 2987         75        8.9                       /music/camila/camila-cabello
# 2988         66        6.4                      /music/vale/black-veil-brides
# 2989         63        6.3                    /music/underworld/tonight-alive
# 2990         66        tbd                           /music/ringthing/jaguwar
# 2991         67        8.0                           /music/blue-madonna/brns
# 2992         90        7.9                       /music/post-/jeff-rosenstock
# 2993         74        tbd                                /music/i/kaukolampi
# 2994         72        tbd                     /music/rainbow-mirror/prurient
# 2995         66        6.7         /music/huncho-jack-jack-huncho/huncho-jack
# 2996         82        8.5                 /music/saturation-iii/brockhampton
# 2997         74        7.6                /music/no-one-ever-really-dies/nerd
# 2998         50        5.7                              /music/revival/eminem
# 2999         87        tbd  /music/box-set-4-curated-by-erykah-badu-box-se...
#
# [3000 rows x 8 columns]

# %%
base_url = "http://www.metacritic.com/"
links = df['links']
genre_list = []
label_list = []
for link in links:
    albumn_link = base_url+link
    hdr = {'User-Agent': 'Mozilla/5.0'}
    req = Request(albumn_link,headers=hdr)
    page = urlopen(req)
    soup = BeautifulSoup(page)
    cropped = soup.find('div',class_="product_data_summary")
    label = cropped.find('li',class_="product_company").find('span',class_="data").contents[0]
#     print(label)
    label_list.append(label)
    genre = cropped.find('li',class_="product_genre").find('span',class_="data").contents
    genre_list.append(genre)
#     print(genre)

df['genre'] = genre_list
df['label'] = label_list
df.to_csv("/afs/cs.wisc.edu/u/s/r/srujith/cs839_stage2/",index=False)
# Out:
# /u/s/r/srujith/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /u/s/r/srujith/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-640f0f156a12> in <module>()
#       7     hdr = {'User-Agent': 'Mozilla/5.0'}
#       8     req = Request(albumn_link,headers=hdr)
# ----> 9     page = urlopen(req)
#      10     soup = BeautifulSoup(page)
#      11     cropped = soup.find('div',class_="product_data_summary")
#
# /u/s/r/srujith/anaconda3/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# /u/s/r/srujith/anaconda3/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     524             req = meth(req)
#     525
# --> 526         response = self._open(req, data)
#     527
#     528         # post-process response
#
# /u/s/r/srujith/anaconda3/lib/python3.6/urllib/request.py in _open(self, req, data)
#     542         protocol = req.type
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#     546             return result
#
# /u/s/r/srujith/anaconda3/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /u/s/r/srujith/anaconda3/lib/python3.6/urllib/request.py in http_open(self, req)
#    1344
#    1345     def http_open(self, req):
# -> 1346         return self.do_open(http.client.HTTPConnection, req)
#    1347
#    1348     http_request = AbstractHTTPHandler.do_request_
#
# /u/s/r/srujith/anaconda3/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1319             except OSError as err: # timeout error
#    1320                 raise URLError(err)
# -> 1321             r = h.getresponse()
#    1322         except:
#    1323             h.close()
#
# /u/s/r/srujith/anaconda3/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /u/s/r/srujith/anaconda3/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /u/s/r/srujith/anaconda3/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /u/s/r/srujith/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:
